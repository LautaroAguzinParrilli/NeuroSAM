# %%
import pandas as pd
import os

# %%
df= pd.read_csv("../Data/all_participants.csv")

# Create a DataFrame from the file paths
folder_path = "/data/lautaro/quasiraw/"

data = []
for root, dirs, files in os.walk(folder_path):
    for file in files:
        file_path = os.path.join(root, file)
        data.append({'ID': file.split('.nii.gz')[0], 'Path': file_path})

file_paths = pd.DataFrame(data)
file_paths['ID'] = file_paths['ID'].str.replace('.nii.gz', '')
file_paths['ID'] = file_paths['ID'].str.replace('_T1w', '')

# %%
print(file_paths)
# Out:
#                            ID  \
# 0         002_S_0413_I1221051
# 1          002_S_0413_I863056
# 2         002_S_1261_I1270020
# 3          002_S_1261_I831065
# 4          002_S_1261_I989320
# ...                       ...
# 9624  sub-OAS31473_sess-d0136
# 9625              sub-ON00400
# 9626              sub-ON01016
# 9627              sub-ON01802
# 9628              sub-ON02693
#
#                                                    Path
# 0     /data/lautaro/quasiraw/002_S_0413_I1221051.nii.gz
# 1      /data/lautaro/quasiraw/002_S_0413_I863056.nii.gz
# 2     /data/lautaro/quasiraw/002_S_1261_I1270020.nii.gz
# 3      /data/lautaro/quasiraw/002_S_1261_I831065.nii.gz
# 4      /data/lautaro/quasiraw/002_S_1261_I989320.nii.gz
# ...                                                 ...
# 9624  /data/lautaro/quasiraw/sub-OAS31473_sess-d0136...
# 9625          /data/lautaro/quasiraw/sub-ON00400.nii.gz
# 9626          /data/lautaro/quasiraw/sub-ON01016.nii.gz
# 9627          /data/lautaro/quasiraw/sub-ON01802.nii.gz
# 9628          /data/lautaro/quasiraw/sub-ON02693.nii.gz
#
# [9629 rows x 2 columns]

# %%
csv_data = pd.merge(df, file_paths, on='ID', how='right')[['Path', 'Age']]

# %%
#ver cuales son las filas con valores nulos
null_rows = csv_data[csv_data.isnull().any(axis=1)]
print("Filas con valores nulos:")
print(null_rows)
# Out:
# Filas con valores nulos:
# Empty DataFrame
# Columns: [Path, Age]
# Index: []

# %%
#guardar csv
csv_data.to_csv("training_data.csv", index=False)
