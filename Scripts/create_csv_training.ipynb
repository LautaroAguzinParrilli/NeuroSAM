# %%
import pandas as pd
import os

# %%
df= pd.read_csv("../Data/all_participants.csv")

# Create a DataFrame from the file paths
folder_path = "/data/lautaro/quasiraw/" #cambiar a training

data = []
for root, dirs, files in os.walk(folder_path):
    for file in files:
        file_path = os.path.join(root, file)
        data.append({'ID': file.split('.nii.gz')[0], 'Path': file_path})

file_paths = pd.DataFrame(data)
file_paths['ID'] = file_paths['ID'].str.replace('.nii.gz', '')
file_paths['ID'] = file_paths['ID'].str.replace('_T1w', '')

# %%
print(file_paths)
# Out:
#                                     ID  \
# 0                 AOMIC-PIOP1_sub-0118
# 1                 AOMIC-PIOP2_sub-0046
# 2                 AOMIC-PIOP2_sub-0202
# 3            PT001_ClevelandCCF_sub-01
# 4                  PT012_CHBMP_sub-099
# ...                                ...
# 13753  PT030_OpenNeuro_ds002886_sub-34
# 13754  PT030_OpenNeuro_ds002886_sub-49
# 13755  PT030_OpenNeuro_ds003095_sub-06
# 13756  PT030_OpenNeuro_ds003126_sub-43
# 13757  PT030_OpenNeuro_ds003126_sub-56
#
#                                                     Path
# 0      /data/lautaro/quasiraw/AOMIC-PIOP1_sub-0118_T1...
# 1      /data/lautaro/quasiraw/AOMIC-PIOP2_sub-0046_T1...
# 2      /data/lautaro/quasiraw/AOMIC-PIOP2_sub-0202_T1...
# 3      /data/lautaro/quasiraw/PT001_ClevelandCCF_sub-...
# 4      /data/lautaro/quasiraw/PT012_CHBMP_sub-099.nii.gz
# ...                                                  ...
# 13753  /data/lautaro/quasiraw/PT030_OpenNeuro_ds00288...
# 13754  /data/lautaro/quasiraw/PT030_OpenNeuro_ds00288...
# 13755  /data/lautaro/quasiraw/PT030_OpenNeuro_ds00309...
# 13756  /data/lautaro/quasiraw/PT030_OpenNeuro_ds00312...
# 13757  /data/lautaro/quasiraw/PT030_OpenNeuro_ds00312...
#
# [13758 rows x 2 columns]

# %%
csv_data = pd.merge(df, file_paths, on='ID', how='right')[['Path', 'Age']]

# %%
#ver cuales son las filas con valores nulos
null_rows = csv_data[csv_data.isnull().any(axis=1)]
print("Filas con valores nulos:")
print(null_rows)
# Out:
# Filas con valores nulos:
# Empty DataFrame
# Columns: [Path, Age]
# Index: []

# %%
#guardar csv
csv_data.to_csv("ext_test_data.csv", index=False)
